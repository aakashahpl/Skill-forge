# %%
from dotenv import load
import textwrap
import os
import re
import json
import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown

# %%
def to_markdown(text):
    text = text.replace("•", "  *")
    return Markdown(textwrap.indent(text, "> ", predicate=lambda _: True))

# %%
load()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
# GOOGLE_API_KEY = ("AIzaSyAo9ciCU1sXR9dUrQzyc17RBMeTV0dji6Q")
print(GOOGLE_API_KEY)

genai.configure(api_key=GOOGLE_API_KEY)
# Out:
# AIzaSyAo9ciCU1sXR9dUrQzyc17RBMeTV0dji6Q

# %%
for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel("gemini-1.0-pro-latest")

# %% [markdown]
# # COURSE GENERATION

# %%
search = "I want to learn about python-basics"
language = "python"

response = model.generate_content(
    f"""
{search}.Make me a course on it. Suggest multiple modules (minimum 5 modules) on the Course along with the estimated time required to complete the course. If topic is a language, start from basics, else focus only on the topic in {language} language. Return the output in JSON in the following format.
Example output:
[
    {{
        "title": 
        "description": 
        "time-required": 
    }},
    {{
        "title": 
        "description": 
        "time-required": 
    }}
    # AND SO ON..
]
"""
)

# %%
print(response)
raw_output = response.text
print("<------------------------------------------------------->")
print(type(raw_output))
print(raw_output)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
# ...

# %%
output_md = to_markdown(raw_output)

# %%
output_md
# Out:
# > ```json
# > [
# >   {
# >     "title": "Module 1: Introduction to Python",
# >     "description": "This module provides an overview of the Python programming language, including its history, features, and basic syntax.",
# >     "time-required": "1 hour"
# >   },
# >   {
# >     "title": "Module 2: Data Types and Variables",
# >     "description": "This module covers the different data types supported by Python, including numbers, strings, lists, and dictionaries. It also explains how to create and manipulate variables.",
# >     "time-required": "1 hour"
# >   },
# >   {
# >     "title": "Module 3: Control Flow",
# >     "description": "This module teaches the basics of control flow in Python, including conditional statements, loops, and functions.",
# >     "time-required": "1 hour 30 minutes"
# >   },
# >   {
# >     "title": "Module 4: File Handling",
# >     "description": "This module covers how to read and write files in Python, including both text and binary files.",
# ...

# %%
str_output = raw_output.replace("json", "").replace("JSON", "").strip("```")
print(str_output)
# Out:
# [
#   {
#     "title": "Module 1: Introduction to Python",
#     "description": "This module provides an overview of the Python programming language, including its history, features, and basic syntax.",
#     "time-required": "1 hour"
#   },
#   {
#     "title": "Module 2: Data Types and Variables",
#     "description": "This module covers the different data types supported by Python, including numbers, strings, lists, and dictionaries. It also explains how to create and manipulate variables.",
#     "time-required": "1 hour"
#   },
#   {
#     "title": "Module 3: Control Flow",
#     "description": "This module teaches the basics of control flow in Python, including conditional statements, loops, and functions.",
#     "time-required": "1 hour 30 minutes"
#   },
#   {
#     "title": "Module 4: File Handling",
#     "description": "This module covers how to read and write files in Python, including both text and binary files.",
#     "time-required": "1 hour"
#   },
#   {
# ...

# %%
json_data = json.loads(str_output)

# Now json_data is a Python object representing the JSON structure
print(json.dumps(json_data, indent=2))
# Out:
# [
#   {
#     "title": "Module 1: Introduction to Python",
#     "description": "This module provides an overview of the Python programming language, including its history, features, and basic syntax.",
#     "time-required": "1 hour"
#   },
#   {
#     "title": "Module 2: Data Types and Variables",
#     "description": "This module covers the different data types supported by Python, including numbers, strings, lists, and dictionaries. It also explains how to create and manipulate variables.",
#     "time-required": "1 hour"
#   },
#   {
#     "title": "Module 3: Control Flow",
#     "description": "This module teaches the basics of control flow in Python, including conditional statements, loops, and functions.",
#     "time-required": "1 hour 30 minutes"
#   },
#   {
#     "title": "Module 4: File Handling",
#     "description": "This module covers how to read and write files in Python, including both text and binary files.",
#     "time-required": "1 hour"
#   },
#   {
# ...

# %% [markdown]
# # CONTENT OF SUB-MODULES

# %%
# response = model.generate_content("""
# Make me course on [queues] in the language [java]. Give me the content of the topic and few quizzes. I want to learn the topic so teach me accordingly, teach me thoroughly. Return me the output ONLY in JSON in the following format dont use "\n" in the output.

# Example output:
# [
#   "topic": [
#     {
#     "content 1": "lorem ipsum"
#     "quiz": [
#         {
#         "question": "lorem ipsum?",
#         "options": ["10", "20", "30", "40"],
#         "correct": "10",
#         }
#       ]
#     },
#     {
#     "content 2": "lorem ipsum"{
#         "quiz": [
#         {
#         "question": "lorem ipsum?",
#         "options": ["10", "20", "30", "40"],
#         "correct": "10",
#         }
#       ]
#     }
#     }
#   }
#   ...OTHER CONTENTS...
#   ]
# ]
# """)
response = model.generate_content("""
**Instructions**

1. **User Input:** I will provide the following:
   * **topic:**  The specific data structure or algorithm to teach
   * **language:** The programming language for examples and implementations

2. **Structure:** Generate course content in JSON...  Ensure you provide minimum four content sections and one quiz per section. Include small code examples where-ever possible. Focus on these core subtopics:
   * Introduction to <topic>
   * Key concepts or techniques within <topic>
   * Very short code examples for the <topic> in <language>
   * Advanced topics within <topic> (if applicable)

                                  
  ```json
  {
    "<topic> in <language>": [
      {
        "content": "Textual explanation of a concept (one or more paragraphs)",
        "quiz": [
          {
            "question": "Multiple-choice question about the concept",
            "options": ["Option 1", "Option 2", "Option 3", "Option 4"],
            "correct": "The single correct answer"
          }
        ],
        "code_example": [
          "code line 1",
          "code line 2",
        ]
      }
       /* More content sections as needed */
    ]
  }
  ```
  
  **User Input**
  * **topic:** Object-Oriented Programming in Python
  * **language:** Python
""")

# %%
# print(response)
raw_output = response.text
print("<------------------------------------------------------->")
print(type(raw_output))
print(raw_output)
# Out:
# <------------------------------------------------------->
# <class 'str'>
# ```json
# {
#   "Object-Oriented Programming in Python": [
#     {
#       "content": "Object-oriented programming (OOP) is a programming paradigm that revolves around the concept of objects. In OOP, data and methods are bundled together to form objects, which can interact with one another through method calls.",
#       "quiz": [
#         {
#           "question": "What is the main principle of OOP?",
#           "options": ["Encapsulation", "Inheritance", "Polymorphism", "Abstraction"],
#           "correct": "Encapsulation"
#         }
#       ],
#       "code_example": []
#     },
#     {
#       "content": "Classes are used to define new object types. They specify the attributes and methods that objects of that type will have. Objects are instances of classes, and they inherit the attributes and methods defined in the class.",
#       "quiz": [
#         {
# ...

# %%
output_md = to_markdown(raw_output)
output_md
# Out:
# > ```json
# > {
# >   "Object-Oriented Programming in Python": [
# >     {
# >       "content": "Object-oriented programming (OOP) is a programming paradigm that revolves around the concept of objects. In OOP, data and methods are bundled together to form objects, which can interact with one another through method calls.",
# >       "quiz": [
# >         {
# >           "question": "What is the main principle of OOP?",
# >           "options": ["Encapsulation", "Inheritance", "Polymorphism", "Abstraction"],
# >           "correct": "Encapsulation"
# >         }
# >       ],
# >       "code_example": []
# >     },
# >     {
# >       "content": "Classes are used to define new object types. They specify the attributes and methods that objects of that type will have. Objects are instances of classes, and they inherit the attributes and methods defined in the class.",
# >       "quiz": [
# >         {
# >           "question": "What is the syntax for creating a class in Python?",
# ...

# %%
str_output = raw_output.replace("json", "").replace("JSON", "").strip("```")
str_output = re.sub(r'[\x00-\x1F\x7F-\xFF]', '', str_output) 
# print(str_output)
json_data = json.loads(str_output)

# Now json_data is a Python object representing the JSON structure
print(json.dumps(json_data, indent=2))
# Out:
# {
#   "Object-Oriented Programming in Python": [
#     {
#       "content": "Object-oriented programming (OOP) is a programming paradigm that revolves around the concept of objects. In OOP, data and methods are bundled together to form objects, which can interact with one another through method calls.",
#       "quiz": [
#         {
#           "question": "What is the main principle of OOP?",
#           "options": [
#             "Encapsulation",
#             "Inheritance",
#             "Polymorphism",
#             "Abstraction"
#           ],
#           "correct": "Encapsulation"
#         }
#       ],
#       "code_example": []
#     },
#     {
#       "content": "Classes are used to define new object types. They specify the attributes and methods that objects of that type will have. Objects are instances of classes, and they inherit the attributes and methods defined in the class.",
#       "quiz": [
#         {
# ...
